# %%
from tqdm import tqdm
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## Scraping from a single Web-Page

# %%
data = []

for sp in soup.find_all('li', class_ = 'col-xs-6 col-sm-4 col-md-3 col-lg-3'):
    
    title = sp.find_all('a')[-1].get('title')
    
    book_link = 'https://books.toscrape.com/catalogue/' + sp.find_all('a')[-1].get('href')
    
    img_link = 'https://books.toscrape.com/' + sp.find('img').get('src')
    
    rating = sp.find('p').get('class')[-1]
    
    price = sp.find('p', class_ = 'price_color').text[1:]
    
    stock = sp.find('p', class_ = 'instock availability').text
    
    data.append([title, book_link, img_link, price, stock])

# %% [markdown]
# ## Scraping from multiple Web_pages

# %%
data = []

for page in tqdm(range(1,51)):
    
    link = 'https://books.toscrape.com/catalogue/page-' + str(page) + '.html'
    res = requests.get(link)
    soup = BeautifulSoup(res.text, 'html.parser')
    
    for sp in soup.find_all('li', class_ = 'col-xs-6 col-sm-4 col-md-3 col-lg-3'):

        title = sp.find_all('a')[-1].get('title')

        book_link = 'https://books.toscrape.com/catalogue/' + sp.find_all('a')[-1].get('href')

        img_link = 'https://books.toscrape.com/' + sp.find('img').get('src')

        rating = sp.find('p').get('class')[-1]

        price = sp.find('p', class_ = 'price_color').text[1:]

        stock = sp.find('p', class_ = 'instock availability').text

        data.append([title, book_link, img_link, rating, price, stock])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [01:25<00:00,  1.72s/it]

# %%
df = pd.DataFrame(data, columns = ['Title', 'Book_Link', 'Img_Link', 'Rating', 'Price', 'Stock'])

df.to_csv('Books_Info.csv', index = False)

# %%
df
# Out:
#                                                  Title  \
# 0                                 A Light in the Attic
# 1                                   Tipping the Velvet
# 2                                           Soumission
# 3                                        Sharp Objects
# 4                Sapiens: A Brief History of Humankind
# ..                                                 ...
# 995  Alice in Wonderland (Alice's Adventures in Won...
# 996   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)
# 997  A Spy's Devotion (The Regency Spies of London #1)
# 998                1st to Die (Women's Murder Club #1)
# 999                 1,000 Places to See Before You Die
#
#                                              Book_Link  \
# 0    https://books.toscrape.com/catalogue/a-light-i...
# 1    https://books.toscrape.com/catalogue/tipping-t...
# 2    https://books.toscrape.com/catalogue/soumissio...
# 3    https://books.toscrape.com/catalogue/sharp-obj...
# ...
